# %% [markdown]
# # 1. Descargar los datos de label studio
# * Recodar exportar las etiquetas en formato YOLO y guardarlas en su carpeta respectivas

# %%
import os
import requests
from dotenv import load_dotenv
from label_studio_sdk import Client

load_dotenv()  # Carga variables desde .env

LABEL_STUDIO_URL = os.getenv("LABEL_STUDIO_URL")
API_KEY = os.getenv("LABEL_STUDIO_API_KEY")

# %%
# Inicializar el cliente
ls = Client(url=LABEL_STUDIO_URL, api_key=API_KEY)

# Obtener todos los proyectos
projects = ls.get_projects()

# Imprimir detalles de cada proyecto
print(f"Proyectos encontrados: {len(projects)}")
for project in projects:
    print(f"ID: {project.id} - Nombre: {project.get_params()['title']}")
# Out:
# Proyectos encontrados: 10
# ID: 14 - Nombre: ParlVotingRowsInColumns
# ID: 13 - Nombre: ParlVotingRows
# ID: 12 - Nombre: ParlVotingColumns
# ID: 11 - Nombre: ParlVotingZones
# ID: 10 - Nombre: TesisFilas
# ID: 6 - Nombre: TesisAsistencia
# ID: 5 - Nombre: TesisVotacion
# ID: 4 - Nombre: TCG-Straight
# ID: 3 - Nombre: TCG-cuadros
# ID: 2 - Nombre: TCG-Segmentation

# %%
def download_images_from_label_studio(project_id: int, output_dir: str):
    # Crear carpeta de salida si no existe
    os.makedirs(output_dir, exist_ok=True)

    # Conectar con Label Studio
    ls = Client(url=LABEL_STUDIO_URL, api_key=API_KEY)
    project = ls.get_project(project_id)
    tasks = project.get_tasks()
    total = len(tasks)
    print(f"Total imágenes encontradas: {total}")
    print(f"Descargando {total} imágenes...")

    for i, task in enumerate(tasks, start=1):
        image_path = task['data'].get('image')
        if image_path:
            full_url = f"{LABEL_STUDIO_URL}{image_path}"
            file_name = os.path.basename(image_path)
            output_path = os.path.join(output_dir, file_name)

            response = requests.get(full_url, headers={'Authorization': f'Token {API_KEY}'}, stream=True)
            if response.status_code == 200:
                with open(output_path, 'wb') as f:
                    for chunk in response.iter_content(chunk_size=8192):
                        f.write(chunk)
                print(f"[{i}/{total}] ✅ Descargado: {file_name}")
            else:
                print(f"[{i}/{total}] ❌ Error al descargar {file_name}: {response.status_code}")
        else:
            print(f"[{i}/{total}] ⚠️ Tarea sin imagen asociada")

# %%
# Votación
download_images_from_label_studio(project_id=14, output_dir='../../data/dataset_etiquetado_filas/b_etiquetados/images')
# Out:
# Total imágenes encontradas: 300
# Descargando 300 imágenes...
# [1/300] ✅ Descargado: c1085f59-093.jpg
# [2/300] ✅ Descargado: be0bd552-094.jpg
# [3/300] ✅ Descargado: 2d4650c0-095.jpg
# [4/300] ✅ Descargado: e1510edf-096.jpg
# [5/300] ✅ Descargado: d57bf94e-097.jpg
# [6/300] ✅ Descargado: 30981a21-098.jpg
# [7/300] ✅ Descargado: e9a32d6c-099.jpg
# [8/300] ✅ Descargado: e10692e5-100.jpg
# [9/300] ✅ Descargado: a167a22e-001.jpg
# [10/300] ✅ Descargado: 8c958289-002.jpg
# [11/300] ✅ Descargado: 102b8451-003.jpg
# [12/300] ✅ Descargado: da0aa65a-004.jpg
# [13/300] ✅ Descargado: bd26e9c8-005.jpg
# [14/300] ✅ Descargado: b99cf13f-006.jpg
# [15/300] ✅ Descargado: 803a7982-007.jpg
# [16/300] ✅ Descargado: 34ffc435-008.jpg
# [17/300] ✅ Descargado: fe7e1864-009.jpg
# [18/300] ✅ Descargado: 9c582527-010.jpg
# [19/300] ✅ Descargado: a944dd42-011.jpg
# [20/300] ✅ Descargado: 97160583-012.jpg
# [21/300] ✅ Descargado: eae40461-013.jpg
# [22/300] ✅ Descargado: e9b4901c-014.jpg
# [23/300] ✅ Descargado: 3c64ddd3-015.jpg
# [24/300] ✅ Descargado: df2feeda-016.jpg
# [25/300] ✅ Descargado: 4d55496a-017.jpg
# [26/300] ✅ Descargado: b753c142-018.jpg
# [27/300] ✅ Descargado: d84c04d7-019.jpg
# [28/300] ✅ Descargado: ba32e908-020.jpg
# [29/300] ✅ Descargado: e5d922e2-021.jpg
# [30/300] ✅ Descargado: f9ab1663-022.jpg
# [31/300] ✅ Descargado: e356e651-023.jpg
# [32/300] ✅ Descargado: 5262b248-024.jpg
# [33/300] ✅ Descargado: 26436416-025.jpg
# [34/300] ✅ Descargado: 625b865f-026.jpg
# [35/300] ✅ Descargado: f7cd611b-027.jpg
# [36/300] ✅ Descargado: 9e7fc283-028.jpg
# [37/300] ✅ Descargado: 903bea2c-029.jpg
# [38/300] ✅ Descargado: 69509ed3-030.jpg
# [39/300] ✅ Descargado: 2547b479-031.jpg
# [40/300] ✅ Descargado: d252299b-032.jpg
# [41/300] ✅ Descargado: 6c0075e1-033.jpg
# [42/300] ✅ Descargado: 3eba970b-034.jpg
# [43/300] ✅ Descargado: 7e607f2a-035.jpg
# [44/300] ✅ Descargado: a3fbbe8e-036.jpg
# [45/300] ✅ Descargado: 872ff09f-037.jpg
# [46/300] ✅ Descargado: 21576d1c-038.jpg
# [47/300] ✅ Descargado: 0bb24af0-039.jpg
# [48/300] ✅ Descargado: 42f87b62-040.jpg
# [49/300] ✅ Descargado: 0eb69711-041.jpg
# [50/300] ✅ Descargado: 906a8b6d-042.jpg
# [51/300] ✅ Descargado: 14bb0422-043.jpg
# [52/300] ✅ Descargado: 4c5bd3cc-044.jpg
# [53/300] ✅ Descargado: f36797b9-045.jpg
# [54/300] ✅ Descargado: 59403d14-046.jpg
# [55/300] ✅ Descargado: a1eedce9-047.jpg
# [56/300] ✅ Descargado: 62ed2292-048.jpg
# [57/300] ✅ Descargado: db379053-049.jpg
# [58/300] ✅ Descargado: 04590f34-050.jpg
# [59/300] ✅ Descargado: 0dd4b436-051.jpg
# [60/300] ✅ Descargado: d0f95626-052.jpg
# [61/300] ✅ Descargado: 019b1d17-053.jpg
# [62/300] ✅ Descargado: 68e858a6-054.jpg
# [63/300] ✅ Descargado: 02ddd784-055.jpg
# [64/300] ✅ Descargado: 2a243928-056.jpg
# [65/300] ✅ Descargado: 7366e173-057.jpg
# [66/300] ✅ Descargado: 05e947c6-058.jpg
# [67/300] ✅ Descargado: caaa04fc-059.jpg
# [68/300] ✅ Descargado: 48114025-060.jpg
# [69/300] ✅ Descargado: 10a4d1f4-061.jpg
# [70/300] ✅ Descargado: a6863778-062.jpg
# [71/300] ✅ Descargado: b35b9ba6-063.jpg
# [72/300] ✅ Descargado: 715f9c83-064.jpg
# [73/300] ✅ Descargado: cfbd2fee-065.jpg
# [74/300] ✅ Descargado: 0c51d9bd-066.jpg
# [75/300] ✅ Descargado: c7fcc279-067.jpg
# [76/300] ✅ Descargado: a12e6e9c-068.jpg
# [77/300] ✅ Descargado: 0d995b1f-069.jpg
# [78/300] ✅ Descargado: 9f323606-070.jpg
# [79/300] ✅ Descargado: 5463aaac-071.jpg
# [80/300] ✅ Descargado: 6e07172b-072.jpg
# [81/300] ✅ Descargado: 47e46003-073.jpg
# [82/300] ✅ Descargado: 47094b5c-074.jpg
# [83/300] ✅ Descargado: b67af12f-075.jpg
# [84/300] ✅ Descargado: f61c6223-076.jpg
# [85/300] ✅ Descargado: 0e0968cc-077.jpg
# [86/300] ✅ Descargado: c4d220b0-078.jpg
# [87/300] ✅ Descargado: 903ad38e-079.jpg
# [88/300] ✅ Descargado: a7525a87-080.jpg
# [89/300] ✅ Descargado: 1371bf46-081.jpg
# [90/300] ✅ Descargado: 2aed8ffa-082.jpg
# [91/300] ✅ Descargado: 2a1c844c-083.jpg
# [92/300] ✅ Descargado: ea45be2d-084.jpg
# [93/300] ✅ Descargado: d3b36aba-085.jpg
# [94/300] ✅ Descargado: 72e7034f-086.jpg
# [95/300] ✅ Descargado: c8f859d6-087.jpg
# [96/300] ✅ Descargado: d974ce7b-088.jpg
# [97/300] ✅ Descargado: e0aeb8fc-089.jpg
# [98/300] ✅ Descargado: 8d42fab6-090.jpg
# [99/300] ✅ Descargado: 8bcadadc-091.jpg
# [100/300] ✅ Descargado: 2d5c1234-092.jpg
# [101/300] ✅ Descargado: 5a9433c8-196.jpg
# [102/300] ✅ Descargado: 916b765f-197.jpg
# [103/300] ✅ Descargado: 33fc2bb7-198.jpg
# [104/300] ✅ Descargado: 03f321f2-199.jpg
# [105/300] ✅ Descargado: e316ebbb-200.jpg
# [106/300] ✅ Descargado: 5f5281a3-101.jpg
# [107/300] ✅ Descargado: 0c9393e2-102.jpg
# [108/300] ✅ Descargado: 89dc4dfc-103.jpg
# [109/300] ✅ Descargado: 74a14000-104.jpg
# [110/300] ✅ Descargado: 4a01d0fa-105.jpg
# [111/300] ✅ Descargado: cc800df7-106.jpg
# [112/300] ✅ Descargado: 66845030-107.jpg
# [113/300] ✅ Descargado: 5736ccc3-108.jpg
# [114/300] ✅ Descargado: 390dd04d-109.jpg
# [115/300] ✅ Descargado: 022a0d1e-110.jpg
# [116/300] ✅ Descargado: 6b7f1f74-111.jpg
# [117/300] ✅ Descargado: 0c714b8e-112.jpg
# [118/300] ✅ Descargado: 38fb2070-113.jpg
# [119/300] ✅ Descargado: f6a1b4ca-114.jpg
# [120/300] ✅ Descargado: 00848348-115.jpg
# [121/300] ✅ Descargado: 1d83101c-116.jpg
# [122/300] ✅ Descargado: 1d7adb95-117.jpg
# [123/300] ✅ Descargado: 51c2c059-118.jpg
# [124/300] ✅ Descargado: fabe3a0c-119.jpg
# [125/300] ✅ Descargado: b769ee87-120.jpg
# [126/300] ✅ Descargado: 53e25e48-121.jpg
# [127/300] ✅ Descargado: cd66e1e6-122.jpg
# [128/300] ✅ Descargado: 6e97657c-123.jpg
# [129/300] ✅ Descargado: 0d6cdf3e-124.jpg
# [130/300] ✅ Descargado: 793e6802-125.jpg
# [131/300] ✅ Descargado: bbc1ffa5-126.jpg
# [132/300] ✅ Descargado: 7d39d65b-127.jpg
# [133/300] ✅ Descargado: 4bf67c6a-128.jpg
# [134/300] ✅ Descargado: 9bdc8850-129.jpg
# [135/300] ✅ Descargado: 339d7fea-130.jpg
# [136/300] ✅ Descargado: f9fe2d3d-131.jpg
# [137/300] ✅ Descargado: 32c5c41a-132.jpg
# [138/300] ✅ Descargado: c8aa91e3-133.jpg
# [139/300] ✅ Descargado: d857ab73-134.jpg
# [140/300] ✅ Descargado: d5d7c179-135.jpg
# [141/300] ✅ Descargado: 6d4168ea-136.jpg
# [142/300] ✅ Descargado: 2ffcd866-137.jpg
# [143/300] ✅ Descargado: 425d771e-138.jpg
# [144/300] ✅ Descargado: 1d4c30b0-139.jpg
# [145/300] ✅ Descargado: 60b8bcc6-140.jpg
# [146/300] ✅ Descargado: be3c4607-141.jpg
# [147/300] ✅ Descargado: 7c80600a-142.jpg
# [148/300] ✅ Descargado: b0349794-143.jpg
# [149/300] ✅ Descargado: 50df206b-144.jpg
# [150/300] ✅ Descargado: dba26641-145.jpg
# [151/300] ✅ Descargado: 76b80eb5-146.jpg
# [152/300] ✅ Descargado: 9156cc12-147.jpg
# [153/300] ✅ Descargado: 0168495b-148.jpg
# [154/300] ✅ Descargado: b3ed07eb-149.jpg
# [155/300] ✅ Descargado: d22e71c7-150.jpg
# [156/300] ✅ Descargado: c21ee22f-151.jpg
# [157/300] ✅ Descargado: 685ab882-152.jpg
# [158/300] ✅ Descargado: 414cb179-153.jpg
# [159/300] ✅ Descargado: dc97bed1-154.jpg
# [160/300] ✅ Descargado: 1659f937-155.jpg
# [161/300] ✅ Descargado: 9d5e9a77-156.jpg
# [162/300] ✅ Descargado: 036230fd-157.jpg
# [163/300] ✅ Descargado: 0a937101-158.jpg
# [164/300] ✅ Descargado: cd3d8721-159.jpg
# [165/300] ✅ Descargado: 6cca759a-160.jpg
# [166/300] ✅ Descargado: f2803cd6-161.jpg
# [167/300] ✅ Descargado: e7da0f8f-162.jpg
# [168/300] ✅ Descargado: bf48ee22-163.jpg
# [169/300] ✅ Descargado: 81e8fa24-164.jpg
# [170/300] ✅ Descargado: e70a00c0-165.jpg
# [171/300] ✅ Descargado: 842f55d5-166.jpg
# [172/300] ✅ Descargado: 029b93d5-167.jpg
# [173/300] ✅ Descargado: 1d2bd824-168.jpg
# [174/300] ✅ Descargado: 9fd7df96-169.jpg
# [175/300] ✅ Descargado: a40c9aa4-170.jpg
# [176/300] ✅ Descargado: e253db4d-171.jpg
# [177/300] ✅ Descargado: 225f8b57-172.jpg
# [178/300] ✅ Descargado: 57db1f0d-173.jpg
# [179/300] ✅ Descargado: 5807ce0c-174.jpg
# [180/300] ✅ Descargado: ec8b865d-175.jpg
# [181/300] ✅ Descargado: 867cdd4d-176.jpg
# [182/300] ✅ Descargado: 8f1934c4-177.jpg
# [183/300] ✅ Descargado: d6ba0087-178.jpg
# [184/300] ✅ Descargado: 9c94af90-179.jpg
# [185/300] ✅ Descargado: 0151e955-180.jpg
# [186/300] ✅ Descargado: 2b87bff2-181.jpg
# [187/300] ✅ Descargado: 61a61003-182.jpg
# [188/300] ✅ Descargado: 5634bb06-183.jpg
# [189/300] ✅ Descargado: 749b540a-184.jpg
# [190/300] ✅ Descargado: c84f7f1c-185.jpg
# [191/300] ✅ Descargado: 64ee58fb-186.jpg
# [192/300] ✅ Descargado: 04d00d3e-187.jpg
# [193/300] ✅ Descargado: 3f19cc2a-188.jpg
# [194/300] ✅ Descargado: d4f01ab7-189.jpg
# [195/300] ✅ Descargado: c5a44009-190.jpg
# [196/300] ✅ Descargado: ca14adc5-191.jpg
# [197/300] ✅ Descargado: d57f531a-192.jpg
# [198/300] ✅ Descargado: 29995177-193.jpg
# [199/300] ✅ Descargado: e26ca374-194.jpg
# [200/300] ✅ Descargado: a92cf231-195.jpg
# [201/300] ✅ Descargado: 591b64b0-284.jpg
# [202/300] ✅ Descargado: 771f6e1c-285.jpg
# [203/300] ✅ Descargado: ddb3f2db-286.jpg
# [204/300] ✅ Descargado: a82b349e-287.jpg
# [205/300] ✅ Descargado: 12fd83c3-288.jpg
# [206/300] ✅ Descargado: 31856019-289.jpg
# [207/300] ✅ Descargado: 9bf72a0b-290.jpg
# [208/300] ✅ Descargado: 9bf313fc-291.jpg
# [209/300] ✅ Descargado: 2caaee7e-292.jpg
# [210/300] ✅ Descargado: 87720c79-293.jpg
# [211/300] ✅ Descargado: 82e6dfac-294.jpg
# [212/300] ✅ Descargado: 03ca11a0-295.jpg
# [213/300] ✅ Descargado: 85a1cdbb-296.jpg
# [214/300] ✅ Descargado: de580800-297.jpg
# [215/300] ✅ Descargado: 16754d54-298.jpg
# [216/300] ✅ Descargado: 585212f8-299.jpg
# [217/300] ✅ Descargado: 49b6bf2d-300.jpg
# [218/300] ✅ Descargado: 2d30f909-201.jpg
# [219/300] ✅ Descargado: ffbb6ead-202.jpg
# [220/300] ✅ Descargado: d83ea0cf-203.jpg
# [221/300] ✅ Descargado: 03a46a56-204.jpg
# [222/300] ✅ Descargado: 3cde63f2-205.jpg
# [223/300] ✅ Descargado: bd61895f-206.jpg
# [224/300] ✅ Descargado: b5e78fcc-207.jpg
# [225/300] ✅ Descargado: 465f422f-208.jpg
# [226/300] ✅ Descargado: a174a6db-209.jpg
# [227/300] ✅ Descargado: 189d9feb-210.jpg
# [228/300] ✅ Descargado: 51de3ecc-211.jpg
# [229/300] ✅ Descargado: 0aa15501-212.jpg
# [230/300] ✅ Descargado: dc91e322-213.jpg
# [231/300] ✅ Descargado: e73cd6bf-214.jpg
# [232/300] ✅ Descargado: 8c2fee8b-215.jpg
# [233/300] ✅ Descargado: ac371ae1-216.jpg
# [234/300] ✅ Descargado: da4c3e1b-217.jpg
# [235/300] ✅ Descargado: d5e4592b-218.jpg
# [236/300] ✅ Descargado: d60a523c-219.jpg
# [237/300] ✅ Descargado: 4c92ae54-220.jpg
# [238/300] ✅ Descargado: c209d7bd-221.jpg
# [239/300] ✅ Descargado: daef3293-222.jpg
# [240/300] ✅ Descargado: c4ee088a-223.jpg
# [241/300] ✅ Descargado: 81ff7841-224.jpg
# [242/300] ✅ Descargado: 9c5fa0f1-225.jpg
# [243/300] ✅ Descargado: e58f9898-226.jpg
# [244/300] ✅ Descargado: 194de165-227.jpg
# [245/300] ✅ Descargado: 21f00dc2-228.jpg
# [246/300] ✅ Descargado: c85cc3ca-229.jpg
# [247/300] ✅ Descargado: 9d319f1c-230.jpg
# [248/300] ✅ Descargado: 28bd0020-231.jpg
# [249/300] ✅ Descargado: f3a49ff8-232.jpg
# [250/300] ✅ Descargado: 7b6d40f6-233.jpg
# [251/300] ✅ Descargado: 6c81efb9-234.jpg
# [252/300] ✅ Descargado: fcfdd4f4-235.jpg
# [253/300] ✅ Descargado: 8ad619a8-236.jpg
# [254/300] ✅ Descargado: 6395d178-237.jpg
# [255/300] ✅ Descargado: fb1f9ef9-238.jpg
# [256/300] ✅ Descargado: 56aebb6b-239.jpg
# [257/300] ✅ Descargado: f90e84db-240.jpg
# [258/300] ✅ Descargado: 0196c1f5-241.jpg
# [259/300] ✅ Descargado: 1515964e-242.jpg
# [260/300] ✅ Descargado: 59f94c78-243.jpg
# [261/300] ✅ Descargado: b7cfa0d0-244.jpg
# [262/300] ✅ Descargado: bb60a093-245.jpg
# [263/300] ✅ Descargado: a47879c4-246.jpg
# [264/300] ✅ Descargado: b8bee3ed-247.jpg
# [265/300] ✅ Descargado: b5ef4275-248.jpg
# [266/300] ✅ Descargado: 7d3e10c1-249.jpg
# [267/300] ✅ Descargado: 094ba443-250.jpg
# [268/300] ✅ Descargado: f935354c-251.jpg
# [269/300] ✅ Descargado: b963f9ac-252.jpg
# [270/300] ✅ Descargado: b3b72427-253.jpg
# [271/300] ✅ Descargado: 30d17884-254.jpg
# [272/300] ✅ Descargado: 09245cdc-255.jpg
# [273/300] ✅ Descargado: 51808ade-256.jpg
# [274/300] ✅ Descargado: f783f9d5-257.jpg
# [275/300] ✅ Descargado: 85a5ece0-258.jpg
# [276/300] ✅ Descargado: b5f6abce-259.jpg
# [277/300] ✅ Descargado: 85b975bc-260.jpg
# [278/300] ✅ Descargado: a6d09329-261.jpg
# [279/300] ✅ Descargado: 503a1ac4-262.jpg
# [280/300] ✅ Descargado: 5455158c-263.jpg
# [281/300] ✅ Descargado: 6d9b773c-264.jpg
# [282/300] ✅ Descargado: 60aaf1be-265.jpg
# [283/300] ✅ Descargado: b2955ae4-266.jpg
# [284/300] ✅ Descargado: 321b1e22-267.jpg
# [285/300] ✅ Descargado: 47f043b5-268.jpg
# [286/300] ✅ Descargado: 226c7266-269.jpg
# [287/300] ✅ Descargado: bd7f2980-270.jpg
# [288/300] ✅ Descargado: 4cdb3b9b-271.jpg
# [289/300] ✅ Descargado: f4f32d80-272.jpg
# [290/300] ✅ Descargado: 02d87ef6-273.jpg
# [291/300] ✅ Descargado: aa559f34-274.jpg
# [292/300] ✅ Descargado: 292b5237-275.jpg
# [293/300] ✅ Descargado: e2d02e03-276.jpg
# [294/300] ✅ Descargado: 5d48733e-277.jpg
# [295/300] ✅ Descargado: e230e40d-278.jpg
# [296/300] ✅ Descargado: 5f6d5087-279.jpg
# [297/300] ✅ Descargado: 69d5af21-280.jpg
# [298/300] ✅ Descargado: 90a43952-281.jpg
# [299/300] ✅ Descargado: 9e50e644-282.jpg
# [300/300] ✅ Descargado: c0c01715-283.jpg

# %% [markdown]
# # B. Probar máscaras

# %%
import os
import cv2
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def visualizar_yolo_labels(nombre_base: str,
                           images_dir='../../data/dataset_etiquetado_filas/b_etiquetados/images',
                           labels_dir='../../data/dataset_etiquetado_filas/b_etiquetados/labels',
                           classes_file='../../data/dataset_etiquetado_filas/b_etiquetados/classes.txt',
                           ext='.jpg'):
    """
    Visualiza una imagen junto con sus anotaciones YOLO.

    Args:
        nombre_base (str): Nombre del archivo sin extensión (por ejemplo: '0ace00af-172_votacion').
        images_dir (str): Ruta al directorio de imágenes.
        labels_dir (str): Ruta al directorio de etiquetas.
        classes_file (str): Ruta al archivo con nombres de clases.
        ext (str): Extensión de la imagen (por defecto '.jpg').
    """
    # Construir rutas
    image_path = os.path.join(images_dir, nombre_base + ext)
    label_path = os.path.join(labels_dir, nombre_base + '.txt')

    # Leer clases
    with open(classes_file, 'r', encoding='utf-8') as f:
        classes = [line.strip() for line in f.readlines()]

    # Leer imagen
    image = cv2.imread(image_path)
    if image is None:
        raise FileNotFoundError(f"No se pudo cargar la imagen: {image_path}")
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    h, w, _ = image.shape

    # Crear figura
    fig, ax = plt.subplots(1, figsize=(10, 10))
    ax.imshow(image)

    # Leer etiquetas
    if os.path.exists(label_path):
        with open(label_path, 'r') as f:
            for line in f:
                parts = line.strip().split()
                if len(parts) != 5:
                    continue  # línea inválida
                class_id = int(parts[0])
                cx, cy, bw, bh = map(float, parts[1:])

                # Convertir a coordenadas absolutas
                x = (cx - bw / 2) * w
                y = (cy - bh / 2) * h
                bw = bw * w
                bh = bh * h

                # Dibujar rectángulo
                rect = patches.Rectangle((x, y), bw, bh, linewidth=2,
                                         edgecolor='lime', facecolor='none')
                ax.add_patch(rect)

                # Añadir nombre de clase
                label = classes[class_id] if class_id < len(classes) else f"Clase {class_id}"
                ax.text(x, y - 5, label, color='lime', fontsize=12,
                        bbox=dict(facecolor='black', alpha=0.5, edgecolor='none'))
    else:
        print(f"⚠️ No se encontró la etiqueta: {label_path}")

    ax.axis('off')
    ax.set_title(f"Visualización: {nombre_base + ext}")
    plt.show()

# %%
visualizar_yolo_labels('c1085f59-093')
