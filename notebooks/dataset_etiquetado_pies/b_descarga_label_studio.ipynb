# %% [markdown]
# # 1. Descargar los datos de label studio
# * Recodar exportar las etiquetas en formato YOLO y guardarlas en su carpeta respectivas

# %%
import os
import requests
from dotenv import load_dotenv
from label_studio_sdk import Client

load_dotenv()  # Carga variables desde .env

LABEL_STUDIO_URL = os.getenv("LABEL_STUDIO_URL")
API_KEY = os.getenv("LABEL_STUDIO_API_KEY")

# %%
# Inicializar el cliente
ls = Client(url=LABEL_STUDIO_URL, api_key=API_KEY)

# Obtener todos los proyectos
projects = ls.get_projects()

# Imprimir detalles de cada proyecto
print(f"Proyectos encontrados: {len(projects)}")
for project in projects:
    print(f"ID: {project.id} - Nombre: {project.get_params()['title']}")
# Out:
# Proyectos encontrados: 11
# ID: 16 - Nombre: ParlVotingFeet
# ID: 14 - Nombre: ParlVotingRowsInColumns
# ID: 13 - Nombre: ParlVotingRows
# ID: 12 - Nombre: ParlVotingColumns
# ID: 11 - Nombre: ParlVotingZones
# ID: 10 - Nombre: TesisFilas
# ID: 6 - Nombre: TesisAsistencia
# ID: 5 - Nombre: TesisVotacion
# ID: 4 - Nombre: TCG-Straight
# ID: 3 - Nombre: TCG-cuadros
# ID: 2 - Nombre: TCG-Segmentation

# %%
def download_images_from_label_studio(project_id: int, output_dir: str):
    # Crear carpeta de salida si no existe
    os.makedirs(output_dir, exist_ok=True)

    # Conectar con Label Studio
    ls = Client(url=LABEL_STUDIO_URL, api_key=API_KEY)
    project = ls.get_project(project_id)
    tasks = project.get_tasks()
    total = len(tasks)
    print(f"Total imágenes encontradas: {total}")
    print(f"Descargando {total} imágenes...")

    for i, task in enumerate(tasks, start=1):
        image_path = task['data'].get('image')
        if image_path:
            full_url = f"{LABEL_STUDIO_URL}{image_path}"
            file_name = os.path.basename(image_path)
            output_path = os.path.join(output_dir, file_name)

            response = requests.get(full_url, headers={'Authorization': f'Token {API_KEY}'}, stream=True)
            if response.status_code == 200:
                with open(output_path, 'wb') as f:
                    for chunk in response.iter_content(chunk_size=8192):
                        f.write(chunk)
                print(f"[{i}/{total}] ✅ Descargado: {file_name}")
            else:
                print(f"[{i}/{total}] ❌ Error al descargar {file_name}: {response.status_code}")
        else:
            print(f"[{i}/{total}] ⚠️ Tarea sin imagen asociada")

# %%
# Votación
download_images_from_label_studio(project_id=16, output_dir='../../data/dataset_etiquetado_pies/b_etiquetados/images')
# Out:
# Total imágenes encontradas: 300
# Descargando 300 imágenes...
# [1/300] ✅ Descargado: 3c5be8e3-100.jpg
# [2/300] ✅ Descargado: 1068d71e-001.jpg
# [3/300] ✅ Descargado: 0a4b5bb6-002.jpg
# [4/300] ✅ Descargado: 942f0e99-003.jpg
# [5/300] ✅ Descargado: 4ce42506-004.jpg
# [6/300] ✅ Descargado: a0e72723-005.jpg
# [7/300] ✅ Descargado: 368c22f3-006.jpg
# [8/300] ✅ Descargado: da9892e8-007.jpg
# [9/300] ✅ Descargado: 64eaddce-008.jpg
# [10/300] ✅ Descargado: 12de7262-009.jpg
# [11/300] ✅ Descargado: 64aa2c41-010.jpg
# [12/300] ✅ Descargado: c37c42ad-011.jpg
# [13/300] ✅ Descargado: dea743ac-012.jpg
# [14/300] ✅ Descargado: 0f92a63c-013.jpg
# [15/300] ✅ Descargado: 4d3ec382-014.jpg
# [16/300] ✅ Descargado: 1b888745-015.jpg
# [17/300] ✅ Descargado: 99fc1629-016.jpg
# [18/300] ✅ Descargado: 68595f53-017.jpg
# [19/300] ✅ Descargado: fe41f2e7-018.jpg
# [20/300] ✅ Descargado: b8ae6c0a-019.jpg
# [21/300] ✅ Descargado: 747a8be2-020.jpg
# [22/300] ✅ Descargado: e62b3cff-021.jpg
# [23/300] ✅ Descargado: 6e39749d-022.jpg
# [24/300] ✅ Descargado: 63f30be8-023.jpg
# [25/300] ✅ Descargado: 65951316-024.jpg
# [26/300] ✅ Descargado: 9c602777-025.jpg
# [27/300] ✅ Descargado: d432acf6-026.jpg
# [28/300] ✅ Descargado: 873b5b16-027.jpg
# [29/300] ✅ Descargado: cbc63f26-028.jpg
# [30/300] ✅ Descargado: 905dffc3-029.jpg
# [31/300] ✅ Descargado: 88eb45c6-030.jpg
# [32/300] ✅ Descargado: 6619a27b-031.jpg
# [33/300] ✅ Descargado: 0cb3ad51-032.jpg
# [34/300] ✅ Descargado: 5eab9969-033.jpg
# [35/300] ✅ Descargado: 5b1da32d-034.jpg
# [36/300] ✅ Descargado: 33e9591a-035.jpg
# [37/300] ✅ Descargado: 00cc6b74-036.jpg
# [38/300] ✅ Descargado: ea434f9d-037.jpg
# [39/300] ✅ Descargado: 8f796138-038.jpg
# [40/300] ✅ Descargado: bee239f2-039.jpg
# [41/300] ✅ Descargado: d1827ea5-040.jpg
# [42/300] ✅ Descargado: 86ecd286-041.jpg
# [43/300] ✅ Descargado: 3df4ca8a-042.jpg
# [44/300] ✅ Descargado: b97080cf-043.jpg
# [45/300] ✅ Descargado: 7b610ee3-044.jpg
# [46/300] ✅ Descargado: 2969072b-045.jpg
# [47/300] ✅ Descargado: 1132f7e1-046.jpg
# [48/300] ✅ Descargado: 943f3b7e-047.jpg
# [49/300] ✅ Descargado: d92a101e-048.jpg
# [50/300] ✅ Descargado: 4c07b41e-049.jpg
# [51/300] ✅ Descargado: c4471e8a-050.jpg
# [52/300] ✅ Descargado: 70569748-051.jpg
# [53/300] ✅ Descargado: acf2249e-052.jpg
# [54/300] ✅ Descargado: 66f77bc6-053.jpg
# [55/300] ✅ Descargado: 9d075dfa-054.jpg
# [56/300] ✅ Descargado: 6275c2c5-055.jpg
# [57/300] ✅ Descargado: 8a1c84c2-056.jpg
# [58/300] ✅ Descargado: 613020cc-057.jpg
# [59/300] ✅ Descargado: 04362442-058.jpg
# [60/300] ✅ Descargado: 518e8e05-059.jpg
# [61/300] ✅ Descargado: 7a13b758-060.jpg
# [62/300] ✅ Descargado: c26dbf3c-061.jpg
# [63/300] ✅ Descargado: 28548b6b-062.jpg
# [64/300] ✅ Descargado: 08b545d4-063.jpg
# [65/300] ✅ Descargado: a3b58747-064.jpg
# [66/300] ✅ Descargado: 0a29b367-065.jpg
# [67/300] ✅ Descargado: 108c35ca-066.jpg
# [68/300] ✅ Descargado: 001959b6-067.jpg
# [69/300] ✅ Descargado: 2c42b712-068.jpg
# [70/300] ✅ Descargado: 1594da41-069.jpg
# [71/300] ✅ Descargado: 14da0104-070.jpg
# [72/300] ✅ Descargado: 5fccc2bb-071.jpg
# [73/300] ✅ Descargado: 1cf43b11-072.jpg
# [74/300] ✅ Descargado: fdea8c49-073.jpg
# [75/300] ✅ Descargado: 48d17979-074.jpg
# [76/300] ✅ Descargado: 9ab02345-075.jpg
# [77/300] ✅ Descargado: f20180c8-076.jpg
# [78/300] ✅ Descargado: a7436917-077.jpg
# [79/300] ✅ Descargado: 59711767-078.jpg
# [80/300] ✅ Descargado: a394fc70-079.jpg
# [81/300] ✅ Descargado: 30815e33-080.jpg
# [82/300] ✅ Descargado: 8a142966-081.jpg
# [83/300] ✅ Descargado: 4758c6ce-082.jpg
# [84/300] ✅ Descargado: e0d79826-083.jpg
# [85/300] ✅ Descargado: 678e84a5-084.jpg
# [86/300] ✅ Descargado: 6bec4a40-085.jpg
# [87/300] ✅ Descargado: 70b1b13a-086.jpg
# [88/300] ✅ Descargado: e7858a75-087.jpg
# [89/300] ✅ Descargado: c6e85dce-088.jpg
# [90/300] ✅ Descargado: 1af5ce5e-089.jpg
# [91/300] ✅ Descargado: 66f6a01e-090.jpg
# [92/300] ✅ Descargado: e1f4413e-091.jpg
# [93/300] ✅ Descargado: 6fed6e53-092.jpg
# [94/300] ✅ Descargado: c8050cd8-093.jpg
# [95/300] ✅ Descargado: d0ba2217-094.jpg
# [96/300] ✅ Descargado: f09a01d5-095.jpg
# [97/300] ✅ Descargado: 48255522-096.jpg
# [98/300] ✅ Descargado: a5754b2e-097.jpg
# [99/300] ✅ Descargado: ea64624a-098.jpg
# [100/300] ✅ Descargado: d5b26658-099.jpg
# [101/300] ✅ Descargado: 6730e1c8-193.jpg
# [102/300] ✅ Descargado: 7fabd6c1-194.jpg
# [103/300] ✅ Descargado: f26d6dae-195.jpg
# [104/300] ✅ Descargado: 5906030e-196.jpg
# [105/300] ✅ Descargado: 04248494-197.jpg
# [106/300] ✅ Descargado: e180e96d-198.jpg
# [107/300] ✅ Descargado: fca6e807-199.jpg
# [108/300] ✅ Descargado: 816f1d01-200.jpg
# [109/300] ✅ Descargado: 09a3bb0c-101.jpg
# [110/300] ✅ Descargado: fb483303-102.jpg
# [111/300] ✅ Descargado: fe2a1a61-103.jpg
# [112/300] ✅ Descargado: c69087ce-104.jpg
# [113/300] ✅ Descargado: 00e4ffb7-105.jpg
# [114/300] ✅ Descargado: adb2157e-106.jpg
# [115/300] ✅ Descargado: 2a3c4315-107.jpg
# [116/300] ✅ Descargado: cc9662c4-108.jpg
# [117/300] ✅ Descargado: 45a466ff-109.jpg
# [118/300] ✅ Descargado: 70e8b049-110.jpg
# [119/300] ✅ Descargado: 355e8a73-111.jpg
# [120/300] ✅ Descargado: 5c4bde4b-112.jpg
# [121/300] ✅ Descargado: ee73c300-113.jpg
# [122/300] ✅ Descargado: 5eb38eb9-114.jpg
# [123/300] ✅ Descargado: 3233fbf8-115.jpg
# [124/300] ✅ Descargado: 142882aa-116.jpg
# [125/300] ✅ Descargado: d6b1079b-117.jpg
# [126/300] ✅ Descargado: fdada87f-118.jpg
# [127/300] ✅ Descargado: cd68a83a-119.jpg
# [128/300] ✅ Descargado: ec464c69-120.jpg
# [129/300] ✅ Descargado: 803f75bd-121.jpg
# [130/300] ✅ Descargado: 2bdfeb74-122.jpg
# [131/300] ✅ Descargado: 550e0d7a-123.jpg
# [132/300] ✅ Descargado: 4568bb82-124.jpg
# [133/300] ✅ Descargado: 46b07d7d-125.jpg
# [134/300] ✅ Descargado: 3410d982-126.jpg
# [135/300] ✅ Descargado: 58880509-127.jpg
# [136/300] ✅ Descargado: 582d6375-128.jpg
# [137/300] ✅ Descargado: f0046619-129.jpg
# [138/300] ✅ Descargado: 39811959-130.jpg
# [139/300] ✅ Descargado: b1fd1838-131.jpg
# [140/300] ✅ Descargado: 3b27f2bc-132.jpg
# [141/300] ✅ Descargado: 5f17ba3e-133.jpg
# [142/300] ✅ Descargado: aebb7b67-134.jpg
# [143/300] ✅ Descargado: a3b8d3f6-135.jpg
# [144/300] ✅ Descargado: 7b82d79f-136.jpg
# [145/300] ✅ Descargado: 26e68fcd-137.jpg
# [146/300] ✅ Descargado: 6c95e159-138.jpg
# [147/300] ✅ Descargado: fe5bf611-139.jpg
# [148/300] ✅ Descargado: 5d1459ae-140.jpg
# [149/300] ✅ Descargado: 07926ed1-141.jpg
# [150/300] ✅ Descargado: 4d58c159-142.jpg
# [151/300] ✅ Descargado: 54215106-143.jpg
# [152/300] ✅ Descargado: 9ca1c23d-144.jpg
# [153/300] ✅ Descargado: 7ee5d032-145.jpg
# [154/300] ✅ Descargado: 3729930b-146.jpg
# [155/300] ✅ Descargado: 6ce6e7a9-147.jpg
# [156/300] ✅ Descargado: e05b156b-148.jpg
# [157/300] ✅ Descargado: c6945e67-149.jpg
# [158/300] ✅ Descargado: e59de715-150.jpg
# [159/300] ✅ Descargado: b9577ff0-151.jpg
# [160/300] ✅ Descargado: 1666fbd5-152.jpg
# [161/300] ✅ Descargado: b74b39cf-153.jpg
# [162/300] ✅ Descargado: b1cd2545-154.jpg
# [163/300] ✅ Descargado: 0590d388-155.jpg
# [164/300] ✅ Descargado: c1bc4ea4-156.jpg
# [165/300] ✅ Descargado: 43f2c05e-157.jpg
# [166/300] ✅ Descargado: 6bedb44a-158.jpg
# [167/300] ✅ Descargado: 9f81005b-159.jpg
# [168/300] ✅ Descargado: 52d27ad6-160.jpg
# [169/300] ✅ Descargado: 1db9fd87-161.jpg
# [170/300] ✅ Descargado: 208eeda5-162.jpg
# [171/300] ✅ Descargado: 9d8e2b51-163.jpg
# [172/300] ✅ Descargado: a130caca-164.jpg
# [173/300] ✅ Descargado: 9f208697-165.jpg
# [174/300] ✅ Descargado: 4f795c6a-166.jpg
# [175/300] ✅ Descargado: f9102165-167.jpg
# [176/300] ✅ Descargado: 8586f807-168.jpg
# [177/300] ✅ Descargado: 9908ce7e-169.jpg
# [178/300] ✅ Descargado: 7554f727-170.jpg
# [179/300] ✅ Descargado: 0484dd06-171.jpg
# [180/300] ✅ Descargado: ea7979f2-172.jpg
# [181/300] ✅ Descargado: f27feaea-173.jpg
# [182/300] ✅ Descargado: 351dee65-174.jpg
# [183/300] ✅ Descargado: 68f0a7be-175.jpg
# [184/300] ✅ Descargado: dc58224a-176.jpg
# [185/300] ✅ Descargado: cac87d04-177.jpg
# [186/300] ✅ Descargado: 0d795c2e-178.jpg
# [187/300] ✅ Descargado: 90a4a8e0-179.jpg
# [188/300] ✅ Descargado: b95df318-180.jpg
# [189/300] ✅ Descargado: 627783f6-181.jpg
# [190/300] ✅ Descargado: 8e47d091-182.jpg
# [191/300] ✅ Descargado: dcae2f71-183.jpg
# [192/300] ✅ Descargado: 55dbd45f-184.jpg
# [193/300] ✅ Descargado: 44f260a8-185.jpg
# [194/300] ✅ Descargado: 0bac65c9-186.jpg
# [195/300] ✅ Descargado: b8b7378a-187.jpg
# [196/300] ✅ Descargado: ee770b1f-188.jpg
# [197/300] ✅ Descargado: 0c2bfdfa-189.jpg
# [198/300] ✅ Descargado: 4eac5726-190.jpg
# [199/300] ✅ Descargado: 3d016f2f-191.jpg
# [200/300] ✅ Descargado: af369231-192.jpg
# [201/300] ✅ Descargado: 50809733-288.jpg
# [202/300] ✅ Descargado: 862ffb91-289.jpg
# [203/300] ✅ Descargado: a8d5e69a-290.jpg
# [204/300] ✅ Descargado: b9fdfd17-291.jpg
# [205/300] ✅ Descargado: 48ded5c7-292.jpg
# [206/300] ✅ Descargado: d4a43176-293.jpg
# [207/300] ✅ Descargado: 1c7d4e4f-294.jpg
# [208/300] ✅ Descargado: 22da0ab3-295.jpg
# [209/300] ✅ Descargado: 384bbc47-296.jpg
# [210/300] ✅ Descargado: a1996f93-297.jpg
# [211/300] ✅ Descargado: 7362380b-298.jpg
# [212/300] ✅ Descargado: 1ea9437b-299.jpg
# [213/300] ✅ Descargado: 1a12cd37-300.jpg
# [214/300] ✅ Descargado: 9eeb4185-201.jpg
# [215/300] ✅ Descargado: b98d7063-202.jpg
# [216/300] ✅ Descargado: 54cdff27-203.jpg
# [217/300] ✅ Descargado: 09f6ab13-204.jpg
# [218/300] ✅ Descargado: 5dfc30f9-205.jpg
# [219/300] ✅ Descargado: d5b23f27-206.jpg
# [220/300] ✅ Descargado: d5a3c3b4-207.jpg
# [221/300] ✅ Descargado: b51de772-208.jpg
# [222/300] ✅ Descargado: 8b6ee52c-209.jpg
# [223/300] ✅ Descargado: 78c5d7df-210.jpg
# [224/300] ✅ Descargado: c3cc282d-211.jpg
# [225/300] ✅ Descargado: 1f84149d-212.jpg
# [226/300] ✅ Descargado: 5a6790ee-213.jpg
# [227/300] ✅ Descargado: a62d8648-214.jpg
# [228/300] ✅ Descargado: 4f4eb0a0-215.jpg
# [229/300] ✅ Descargado: e5f5ad21-216.jpg
# [230/300] ✅ Descargado: 19af1e4a-217.jpg
# [231/300] ✅ Descargado: 80d2d5e3-218.jpg
# [232/300] ✅ Descargado: 67f61fc1-219.jpg
# [233/300] ✅ Descargado: b67b90f8-220.jpg
# [234/300] ✅ Descargado: de65641b-221.jpg
# [235/300] ✅ Descargado: 8db667c0-222.jpg
# [236/300] ✅ Descargado: d125af28-223.jpg
# [237/300] ✅ Descargado: c27899ae-224.jpg
# [238/300] ✅ Descargado: b07c05e9-225.jpg
# [239/300] ✅ Descargado: f57c362f-226.jpg
# [240/300] ✅ Descargado: 97c67b74-227.jpg
# [241/300] ✅ Descargado: 2e48c612-228.jpg
# [242/300] ✅ Descargado: 00f44026-229.jpg
# [243/300] ✅ Descargado: 4b660750-230.jpg
# [244/300] ✅ Descargado: 07e36232-231.jpg
# [245/300] ✅ Descargado: dfe60034-232.jpg
# [246/300] ✅ Descargado: cce77450-233.jpg
# [247/300] ✅ Descargado: c106f969-234.jpg
# [248/300] ✅ Descargado: eeeb17eb-235.jpg
# [249/300] ✅ Descargado: a32a979c-236.jpg
# [250/300] ✅ Descargado: dcfa13fb-237.jpg
# [251/300] ✅ Descargado: 948509cb-238.jpg
# [252/300] ✅ Descargado: d701526f-239.jpg
# [253/300] ✅ Descargado: 7f1c9c0d-240.jpg
# [254/300] ✅ Descargado: d4551173-241.jpg
# [255/300] ✅ Descargado: 1470be04-242.jpg
# [256/300] ✅ Descargado: d1fe5b5c-243.jpg
# [257/300] ✅ Descargado: 113db6e8-244.jpg
# [258/300] ✅ Descargado: 6aa99438-245.jpg
# [259/300] ✅ Descargado: 5d6a4eca-246.jpg
# [260/300] ✅ Descargado: 6a191b11-247.jpg
# [261/300] ✅ Descargado: 07a36c6d-248.jpg
# [262/300] ✅ Descargado: a58ee5a0-249.jpg
# [263/300] ✅ Descargado: a326eb21-250.jpg
# [264/300] ✅ Descargado: e827f596-251.jpg
# [265/300] ✅ Descargado: 62ca1a70-252.jpg
# [266/300] ✅ Descargado: ed1f949a-253.jpg
# [267/300] ✅ Descargado: 9deb9883-254.jpg
# [268/300] ✅ Descargado: f7c09cb9-255.jpg
# [269/300] ✅ Descargado: ab999f27-256.jpg
# [270/300] ✅ Descargado: 26d3936b-257.jpg
# [271/300] ✅ Descargado: 5ecd9f84-258.jpg
# [272/300] ✅ Descargado: 411c379d-259.jpg
# [273/300] ✅ Descargado: c594865f-260.jpg
# [274/300] ✅ Descargado: 46a90c4d-261.jpg
# [275/300] ✅ Descargado: 52bca1bd-262.jpg
# [276/300] ✅ Descargado: 4224438e-263.jpg
# [277/300] ✅ Descargado: edd1a41f-264.jpg
# [278/300] ✅ Descargado: 00e81c93-265.jpg
# [279/300] ✅ Descargado: 391f67a5-266.jpg
# [280/300] ✅ Descargado: dec27925-267.jpg
# [281/300] ✅ Descargado: 4f098a1a-268.jpg
# [282/300] ✅ Descargado: 2225fd6e-269.jpg
# [283/300] ✅ Descargado: e4eab103-270.jpg
# [284/300] ✅ Descargado: 586715d8-271.jpg
# [285/300] ✅ Descargado: 0fc9eff6-272.jpg
# [286/300] ✅ Descargado: 8799f4b3-273.jpg
# [287/300] ✅ Descargado: c05276e2-274.jpg
# [288/300] ✅ Descargado: 8c9e0e34-275.jpg
# [289/300] ✅ Descargado: cefbd646-276.jpg
# [290/300] ✅ Descargado: 8e04b77f-277.jpg
# [291/300] ✅ Descargado: 10fbd59d-278.jpg
# [292/300] ✅ Descargado: db7dcd70-279.jpg
# [293/300] ✅ Descargado: 5a121213-280.jpg
# [294/300] ✅ Descargado: 892164b1-281.jpg
# [295/300] ✅ Descargado: 64facdcf-282.jpg
# [296/300] ✅ Descargado: 1c3a8704-283.jpg
# [297/300] ✅ Descargado: 25df9bfb-284.jpg
# [298/300] ✅ Descargado: 0662ea9e-285.jpg
# [299/300] ✅ Descargado: 4c316ec5-286.jpg
# [300/300] ✅ Descargado: 49d9b1a0-287.jpg

# %% [markdown]
# # B. Probar máscaras

# %%
import os
import cv2
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def visualizar_yolo_labels(nombre_base: str,
                           images_dir='../../data/dataset_etiquetado_pies/b_etiquetados/images',
                           labels_dir='../../data/dataset_etiquetado_pies/b_etiquetados/labels',
                           classes_file='../../data/dataset_etiquetado_pies/b_etiquetados/classes.txt',
                           ext='.jpg'):
    """
    Visualiza una imagen junto con sus anotaciones YOLO.

    Args:
        nombre_base (str): Nombre del archivo sin extensión (por ejemplo: '0ace00af-172_votacion').
        images_dir (str): Ruta al directorio de imágenes.
        labels_dir (str): Ruta al directorio de etiquetas.
        classes_file (str): Ruta al archivo con nombres de clases.
        ext (str): Extensión de la imagen (por defecto '.jpg').
    """
    # Construir rutas
    image_path = os.path.join(images_dir, nombre_base + ext)
    label_path = os.path.join(labels_dir, nombre_base + '.txt')

    # Leer clases
    with open(classes_file, 'r', encoding='utf-8') as f:
        classes = [line.strip() for line in f.readlines()]

    # Leer imagen
    image = cv2.imread(image_path)
    if image is None:
        raise FileNotFoundError(f"No se pudo cargar la imagen: {image_path}")
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    h, w, _ = image.shape

    # Crear figura
    fig, ax = plt.subplots(1, figsize=(10, 10))
    ax.imshow(image)

    # Leer etiquetas
    if os.path.exists(label_path):
        with open(label_path, 'r') as f:
            for line in f:
                parts = line.strip().split()
                if len(parts) != 5:
                    continue  # línea inválida
                class_id = int(parts[0])
                cx, cy, bw, bh = map(float, parts[1:])

                # Convertir a coordenadas absolutas
                x = (cx - bw / 2) * w
                y = (cy - bh / 2) * h
                bw = bw * w
                bh = bh * h

                # Dibujar rectángulo
                rect = patches.Rectangle((x, y), bw, bh, linewidth=2,
                                         edgecolor='lime', facecolor='none')
                ax.add_patch(rect)

                # Añadir nombre de clase
                label = classes[class_id] if class_id < len(classes) else f"Clase {class_id}"
                ax.text(x, y - 5, label, color='lime', fontsize=12,
                        bbox=dict(facecolor='black', alpha=0.5, edgecolor='none'))
    else:
        print(f"⚠️ No se encontró la etiqueta: {label_path}")

    ax.axis('off')
    ax.set_title(f"Visualización: {nombre_base + ext}")
    plt.show()

# %%
visualizar_yolo_labels('0a4b5bb6-002')
