# %% [markdown]
# # 1. Descargar los datos de label studio
# * Recodar exportar las etiquetas en formato YOLO y guardarlas en su carpeta respectivas

# %%
import os
import requests
from dotenv import load_dotenv
from label_studio_sdk import Client

load_dotenv()  # Carga variables desde .env

LABEL_STUDIO_URL = os.getenv("LABEL_STUDIO_URL")
API_KEY = os.getenv("LABEL_STUDIO_API_KEY")

# %%
# Inicializar el cliente
ls = Client(url=LABEL_STUDIO_URL, api_key=API_KEY)

# Obtener todos los proyectos
projects = ls.get_projects()

# Imprimir detalles de cada proyecto
print(f"Proyectos encontrados: {len(projects)}")
for project in projects:
    print(f"ID: {project.id} - Nombre: {project.get_params()['title']}")
# Out:
# Proyectos encontrados: 12
# ID: 17 - Nombre: ParlVotingPresident
# ID: 16 - Nombre: ParlVotingFeet
# ID: 14 - Nombre: ParlVotingRowsInColumns
# ID: 13 - Nombre: ParlVotingRows
# ID: 12 - Nombre: ParlVotingColumns
# ID: 11 - Nombre: ParlVotingZones
# ID: 10 - Nombre: TesisFilas
# ID: 6 - Nombre: TesisAsistencia
# ID: 5 - Nombre: TesisVotacion
# ID: 4 - Nombre: TCG-Straight
# ID: 3 - Nombre: TCG-cuadros
# ID: 2 - Nombre: TCG-Segmentation

# %%
def download_images_from_label_studio(project_id: int, output_dir: str):
    # Crear carpeta de salida si no existe
    os.makedirs(output_dir, exist_ok=True)

    # Conectar con Label Studio
    ls = Client(url=LABEL_STUDIO_URL, api_key=API_KEY)
    project = ls.get_project(project_id)
    tasks = project.get_tasks()
    total = len(tasks)
    print(f"Total imágenes encontradas: {total}")
    print(f"Descargando {total} imágenes...")

    for i, task in enumerate(tasks, start=1):
        image_path = task['data'].get('image')
        if image_path:
            full_url = f"{LABEL_STUDIO_URL}{image_path}"
            file_name = os.path.basename(image_path)
            output_path = os.path.join(output_dir, file_name)

            response = requests.get(full_url, headers={'Authorization': f'Token {API_KEY}'}, stream=True)
            if response.status_code == 200:
                with open(output_path, 'wb') as f:
                    for chunk in response.iter_content(chunk_size=8192):
                        f.write(chunk)
                print(f"[{i}/{total}] ✅ Descargado: {file_name}")
            else:
                print(f"[{i}/{total}] ❌ Error al descargar {file_name}: {response.status_code}")
        else:
            print(f"[{i}/{total}] ⚠️ Tarea sin imagen asociada")

# %%
# Votación
download_images_from_label_studio(project_id=17, output_dir='../../data/dataset_etiquetado_presidente/b_etiquetados/images')
# Out:
# Total imágenes encontradas: 300
# Descargando 300 imágenes...
# [1/300] ✅ Descargado: 3bf08289-005.jpg
# [2/300] ✅ Descargado: 975d6887-006.jpg
# [3/300] ✅ Descargado: d211b8e0-007.jpg
# [4/300] ✅ Descargado: 8068fc9e-008.jpg
# [5/300] ✅ Descargado: 22569675-009.jpg
# [6/300] ✅ Descargado: 51d40737-010.jpg
# [7/300] ✅ Descargado: eee0302f-011.jpg
# [8/300] ✅ Descargado: 181f8efb-012.jpg
# [9/300] ✅ Descargado: 0d5785fa-013.jpg
# [10/300] ✅ Descargado: c67bae80-014.jpg
# [11/300] ✅ Descargado: e71d994b-015.jpg
# [12/300] ✅ Descargado: c73a6551-016.jpg
# [13/300] ✅ Descargado: d0e84cda-017.jpg
# [14/300] ✅ Descargado: a4a918cb-018.jpg
# [15/300] ✅ Descargado: 89022b19-019.jpg
# [16/300] ✅ Descargado: 7002fec2-020.jpg
# [17/300] ✅ Descargado: aaa965c9-021.jpg
# [18/300] ✅ Descargado: 68f242c5-022.jpg
# [19/300] ✅ Descargado: 5e9e29b7-023.jpg
# [20/300] ✅ Descargado: 71a11006-024.jpg
# [21/300] ✅ Descargado: 2d440d98-025.jpg
# [22/300] ✅ Descargado: de61013c-026.jpg
# [23/300] ✅ Descargado: d779f09f-027.jpg
# [24/300] ✅ Descargado: 342b0af8-028.jpg
# [25/300] ✅ Descargado: 29348f21-029.jpg
# [26/300] ✅ Descargado: 2d3975f4-030.jpg
# [27/300] ✅ Descargado: d463531c-031.jpg
# [28/300] ✅ Descargado: 39374215-032.jpg
# [29/300] ✅ Descargado: c1804aae-033.jpg
# [30/300] ✅ Descargado: 3e59c07f-034.jpg
# [31/300] ✅ Descargado: 9be38909-035.jpg
# [32/300] ✅ Descargado: 80a7b8fe-036.jpg
# [33/300] ✅ Descargado: 9c51df2e-037.jpg
# [34/300] ✅ Descargado: 3143e6ed-038.jpg
# [35/300] ✅ Descargado: 7269eb38-039.jpg
# [36/300] ✅ Descargado: 486d712b-040.jpg
# [37/300] ✅ Descargado: 8ad4af1e-041.jpg
# [38/300] ✅ Descargado: 716f41a1-042.jpg
# [39/300] ✅ Descargado: 80642abf-043.jpg
# [40/300] ✅ Descargado: 6c8bbfcd-044.jpg
# [41/300] ✅ Descargado: 701e104c-045.jpg
# [42/300] ✅ Descargado: 9c7bad78-046.jpg
# [43/300] ✅ Descargado: 8b5ea0d6-047.jpg
# [44/300] ✅ Descargado: b49365a2-048.jpg
# [45/300] ✅ Descargado: 4ec91073-049.jpg
# [46/300] ✅ Descargado: b036919c-050.jpg
# [47/300] ✅ Descargado: 9d488d04-051.jpg
# [48/300] ✅ Descargado: 9ccc692d-052.jpg
# [49/300] ✅ Descargado: 425da49e-053.jpg
# [50/300] ✅ Descargado: b47f7d2a-054.jpg
# [51/300] ✅ Descargado: 2659ebf0-055.jpg
# [52/300] ✅ Descargado: 9da4f770-056.jpg
# [53/300] ✅ Descargado: b431433b-057.jpg
# [54/300] ✅ Descargado: b584b189-058.jpg
# [55/300] ✅ Descargado: ba49b621-059.jpg
# [56/300] ✅ Descargado: 9dba2cd7-060.jpg
# [57/300] ✅ Descargado: d930cc72-061.jpg
# [58/300] ✅ Descargado: f6bbd909-062.jpg
# [59/300] ✅ Descargado: 22114b93-063.jpg
# [60/300] ✅ Descargado: afdb7969-064.jpg
# [61/300] ✅ Descargado: ef3419b2-065.jpg
# [62/300] ✅ Descargado: d6197abe-066.jpg
# [63/300] ✅ Descargado: bbeba845-067.jpg
# [64/300] ✅ Descargado: a4a0f600-068.jpg
# [65/300] ✅ Descargado: 5135aad0-069.jpg
# [66/300] ✅ Descargado: 29e2c8ad-070.jpg
# [67/300] ✅ Descargado: 790e1994-071.jpg
# [68/300] ✅ Descargado: 8e344547-072.jpg
# [69/300] ✅ Descargado: bbe399b8-073.jpg
# [70/300] ✅ Descargado: 53f1372e-074.jpg
# [71/300] ✅ Descargado: 298084e2-075.jpg
# [72/300] ✅ Descargado: f2bf08c8-076.jpg
# [73/300] ✅ Descargado: 9d9d2fa6-077.jpg
# [74/300] ✅ Descargado: 20e500aa-078.jpg
# [75/300] ✅ Descargado: 108053a0-079.jpg
# [76/300] ✅ Descargado: d0aa51b1-080.jpg
# [77/300] ✅ Descargado: 0eab1ed7-081.jpg
# [78/300] ✅ Descargado: 5db840b1-082.jpg
# [79/300] ✅ Descargado: 01b01784-083.jpg
# [80/300] ✅ Descargado: 4265bf1a-084.jpg
# [81/300] ✅ Descargado: 45b862fa-085.jpg
# [82/300] ✅ Descargado: 6d7603b7-086.jpg
# [83/300] ✅ Descargado: c7bb1c69-087.jpg
# [84/300] ✅ Descargado: 5e528f1b-088.jpg
# [85/300] ✅ Descargado: e052e129-089.jpg
# [86/300] ✅ Descargado: 5b81e323-090.jpg
# [87/300] ✅ Descargado: 08355bfe-091.jpg
# [88/300] ✅ Descargado: 54bb7a03-092.jpg
# [89/300] ✅ Descargado: 140e0d31-093.jpg
# [90/300] ✅ Descargado: 94e14265-094.jpg
# [91/300] ✅ Descargado: 6b5f7209-095.jpg
# [92/300] ✅ Descargado: e239ae35-096.jpg
# [93/300] ✅ Descargado: c782519c-097.jpg
# [94/300] ✅ Descargado: 6e81166d-098.jpg
# [95/300] ✅ Descargado: 1c81b560-099.jpg
# [96/300] ✅ Descargado: 30b846e7-100.jpg
# [97/300] ✅ Descargado: 8c1b8b59-001.jpg
# [98/300] ✅ Descargado: 72c4dfcd-002.jpg
# [99/300] ✅ Descargado: bff0a6b6-003.jpg
# [100/300] ✅ Descargado: 18d59499-004.jpg
# [101/300] ✅ Descargado: 569970fe-191.jpg
# [102/300] ✅ Descargado: 8665104f-192.jpg
# [103/300] ✅ Descargado: a9c5fb93-193.jpg
# [104/300] ✅ Descargado: 813165a4-194.jpg
# [105/300] ✅ Descargado: 1be78d43-195.jpg
# [106/300] ✅ Descargado: 99220ab5-196.jpg
# [107/300] ✅ Descargado: d7234f19-197.jpg
# [108/300] ✅ Descargado: d389d297-198.jpg
# [109/300] ✅ Descargado: ab2d828f-199.jpg
# [110/300] ✅ Descargado: 4faf2bdd-200.jpg
# [111/300] ✅ Descargado: 518d5665-101.jpg
# [112/300] ✅ Descargado: d2e13bcd-102.jpg
# [113/300] ✅ Descargado: ca4369b5-103.jpg
# [114/300] ✅ Descargado: 5de43af9-104.jpg
# [115/300] ✅ Descargado: 42c013d0-105.jpg
# [116/300] ✅ Descargado: 263708bf-106.jpg
# [117/300] ✅ Descargado: b5a54cbb-107.jpg
# [118/300] ✅ Descargado: 9b7f604a-108.jpg
# [119/300] ✅ Descargado: d4f04bda-109.jpg
# [120/300] ✅ Descargado: bfe7c7ee-110.jpg
# [121/300] ✅ Descargado: cedbd3b1-111.jpg
# [122/300] ✅ Descargado: 44574021-112.jpg
# [123/300] ✅ Descargado: da3eb625-113.jpg
# [124/300] ✅ Descargado: a015886f-114.jpg
# [125/300] ✅ Descargado: 827615d6-115.jpg
# [126/300] ✅ Descargado: 12bf6631-116.jpg
# [127/300] ✅ Descargado: c985051d-117.jpg
# [128/300] ✅ Descargado: 69bfcdaf-118.jpg
# [129/300] ✅ Descargado: 9ff0513d-119.jpg
# [130/300] ✅ Descargado: 28707a6c-120.jpg
# [131/300] ✅ Descargado: b6851801-121.jpg
# [132/300] ✅ Descargado: 47f1ce17-122.jpg
# [133/300] ✅ Descargado: 1a99dd82-123.jpg
# [134/300] ✅ Descargado: 993d4bf8-124.jpg
# [135/300] ✅ Descargado: 1623ba83-125.jpg
# [136/300] ✅ Descargado: fb3d8326-126.jpg
# [137/300] ✅ Descargado: 683566a2-127.jpg
# [138/300] ✅ Descargado: 47f3036d-128.jpg
# [139/300] ✅ Descargado: 7af91581-129.jpg
# [140/300] ✅ Descargado: 283b31ce-130.jpg
# [141/300] ✅ Descargado: 40071119-131.jpg
# [142/300] ✅ Descargado: d1ff3b00-132.jpg
# [143/300] ✅ Descargado: a0e6f16c-133.jpg
# [144/300] ✅ Descargado: 5a5f76f2-134.jpg
# [145/300] ✅ Descargado: 587fb078-135.jpg
# [146/300] ✅ Descargado: aa4bf8c3-136.jpg
# [147/300] ✅ Descargado: 2ad6bbaf-137.jpg
# [148/300] ✅ Descargado: 52c854cd-138.jpg
# [149/300] ✅ Descargado: c922d9d7-139.jpg
# [150/300] ✅ Descargado: 4d2c2a2c-140.jpg
# [151/300] ✅ Descargado: b55890cf-141.jpg
# [152/300] ✅ Descargado: d0986a22-142.jpg
# [153/300] ✅ Descargado: 2a7b6fe5-143.jpg
# [154/300] ✅ Descargado: 4c60b501-144.jpg
# [155/300] ✅ Descargado: 9e2f7920-145.jpg
# [156/300] ✅ Descargado: 68cae6d8-146.jpg
# [157/300] ✅ Descargado: 0016456f-147.jpg
# [158/300] ✅ Descargado: e029756a-148.jpg
# [159/300] ✅ Descargado: 33ca1bba-149.jpg
# [160/300] ✅ Descargado: a6cd9ff4-150.jpg
# [161/300] ✅ Descargado: 4b67eb3d-151.jpg
# [162/300] ✅ Descargado: de36d103-152.jpg
# [163/300] ✅ Descargado: 59c25777-153.jpg
# [164/300] ✅ Descargado: bcec35e9-154.jpg
# [165/300] ✅ Descargado: 5113e932-155.jpg
# [166/300] ✅ Descargado: a7bebc19-156.jpg
# [167/300] ✅ Descargado: 7dadb3b7-157.jpg
# [168/300] ✅ Descargado: e0c1ef57-158.jpg
# [169/300] ✅ Descargado: 8055d735-159.jpg
# [170/300] ✅ Descargado: 3d105d4e-160.jpg
# [171/300] ✅ Descargado: 93d7be5c-161.jpg
# [172/300] ✅ Descargado: be51493f-162.jpg
# [173/300] ✅ Descargado: 3e8d72e5-163.jpg
# [174/300] ✅ Descargado: b9bc5f69-164.jpg
# [175/300] ✅ Descargado: 6f6bfb64-165.jpg
# [176/300] ✅ Descargado: e609d4d0-166.jpg
# [177/300] ✅ Descargado: c7298873-167.jpg
# [178/300] ✅ Descargado: 85fe314d-168.jpg
# [179/300] ✅ Descargado: 3054262e-169.jpg
# [180/300] ✅ Descargado: 2aa6796c-170.jpg
# [181/300] ✅ Descargado: 4454ebe4-171.jpg
# [182/300] ✅ Descargado: ffdc883f-172.jpg
# [183/300] ✅ Descargado: c486dc70-173.jpg
# [184/300] ✅ Descargado: 1a85b3a8-174.jpg
# [185/300] ✅ Descargado: 2b4bb491-175.jpg
# [186/300] ✅ Descargado: cac0d02d-176.jpg
# [187/300] ✅ Descargado: 8dd3c077-177.jpg
# [188/300] ✅ Descargado: 1c9d0787-178.jpg
# [189/300] ✅ Descargado: 857d8d90-179.jpg
# [190/300] ✅ Descargado: 47688109-180.jpg
# [191/300] ✅ Descargado: 01fed8f5-181.jpg
# [192/300] ✅ Descargado: a59a4074-182.jpg
# [193/300] ✅ Descargado: ab85afa5-183.jpg
# [194/300] ✅ Descargado: eba97926-184.jpg
# [195/300] ✅ Descargado: f81a4321-185.jpg
# [196/300] ✅ Descargado: 12647546-186.jpg
# [197/300] ✅ Descargado: ea4feccb-187.jpg
# [198/300] ✅ Descargado: 45d3a407-188.jpg
# [199/300] ✅ Descargado: b74fa97f-189.jpg
# [200/300] ✅ Descargado: 382d2339-190.jpg
# [201/300] ✅ Descargado: 2680a7f3-292.jpg
# [202/300] ✅ Descargado: 5d199506-293.jpg
# [203/300] ✅ Descargado: 6f017816-294.jpg
# [204/300] ✅ Descargado: 29921ea2-295.jpg
# [205/300] ✅ Descargado: 713fc5fb-296.jpg
# [206/300] ✅ Descargado: f372c013-297.jpg
# [207/300] ✅ Descargado: 4e758199-298.jpg
# [208/300] ✅ Descargado: e689ed98-299.jpg
# [209/300] ✅ Descargado: 68d0c503-300.jpg
# [210/300] ✅ Descargado: 59d9fba2-201.jpg
# [211/300] ✅ Descargado: 0a445921-202.jpg
# [212/300] ✅ Descargado: 4ad6bd25-203.jpg
# [213/300] ✅ Descargado: 380e28c1-204.jpg
# [214/300] ✅ Descargado: 4aa3a709-205.jpg
# [215/300] ✅ Descargado: 23c10d67-206.jpg
# [216/300] ✅ Descargado: eba96285-207.jpg
# [217/300] ✅ Descargado: bde242a7-208.jpg
# [218/300] ✅ Descargado: 1424c1dc-209.jpg
# [219/300] ✅ Descargado: f0b0ba18-210.jpg
# [220/300] ✅ Descargado: ea484bd5-211.jpg
# [221/300] ✅ Descargado: 44c40cbf-212.jpg
# [222/300] ✅ Descargado: d2d164e5-213.jpg
# [223/300] ✅ Descargado: 039bfa69-214.jpg
# [224/300] ✅ Descargado: 0717be54-215.jpg
# [225/300] ✅ Descargado: f7eb8b28-216.jpg
# [226/300] ✅ Descargado: c171dcf5-217.jpg
# [227/300] ✅ Descargado: 2e6b02fc-218.jpg
# [228/300] ✅ Descargado: 9fd7325b-219.jpg
# [229/300] ✅ Descargado: 484b5397-220.jpg
# [230/300] ✅ Descargado: 500bda8e-221.jpg
# [231/300] ✅ Descargado: e8c392be-222.jpg
# [232/300] ✅ Descargado: e8d3a3a5-223.jpg
# [233/300] ✅ Descargado: 0d9dd317-224.jpg
# [234/300] ✅ Descargado: 8102b73f-225.jpg
# [235/300] ✅ Descargado: 64d94266-226.jpg
# [236/300] ✅ Descargado: 6e52639b-227.jpg
# [237/300] ✅ Descargado: eac7149f-228.jpg
# [238/300] ✅ Descargado: a0007aa7-229.jpg
# [239/300] ✅ Descargado: 8fc642d1-230.jpg
# [240/300] ✅ Descargado: 0acff1c1-231.jpg
# [241/300] ✅ Descargado: a94aac60-232.jpg
# [242/300] ✅ Descargado: b4a3c163-233.jpg
# [243/300] ✅ Descargado: e37b890b-234.jpg
# [244/300] ✅ Descargado: a9d0c232-235.jpg
# [245/300] ✅ Descargado: 5e4405f1-236.jpg
# [246/300] ✅ Descargado: 8ff03e41-237.jpg
# [247/300] ✅ Descargado: 406febb0-238.jpg
# [248/300] ✅ Descargado: 33fb49f8-239.jpg
# [249/300] ✅ Descargado: 991f0dd7-240.jpg
# [250/300] ✅ Descargado: cd0236a7-241.jpg
# [251/300] ✅ Descargado: a4be8478-242.jpg
# [252/300] ✅ Descargado: 18d8d8e3-243.jpg
# [253/300] ✅ Descargado: ceb77a22-244.jpg
# [254/300] ✅ Descargado: f975ec77-245.jpg
# [255/300] ✅ Descargado: 0d12f981-246.jpg
# [256/300] ✅ Descargado: a79c532e-247.jpg
# [257/300] ✅ Descargado: 67bae2bf-248.jpg
# [258/300] ✅ Descargado: d365e3b6-249.jpg
# [259/300] ✅ Descargado: 7b0f764a-250.jpg
# [260/300] ✅ Descargado: 775525f4-251.jpg
# [261/300] ✅ Descargado: b3ef177c-252.jpg
# [262/300] ✅ Descargado: 4e133a4f-253.jpg
# [263/300] ✅ Descargado: 3533b622-254.jpg
# [264/300] ✅ Descargado: 949c35a0-255.jpg
# [265/300] ✅ Descargado: 066016dd-256.jpg
# [266/300] ✅ Descargado: 4953ec8d-257.jpg
# [267/300] ✅ Descargado: 72435af3-258.jpg
# [268/300] ✅ Descargado: 13183b7c-259.jpg
# [269/300] ✅ Descargado: 7cd25578-260.jpg
# [270/300] ✅ Descargado: be0adef8-261.jpg
# [271/300] ✅ Descargado: 690c44a1-262.jpg
# [272/300] ✅ Descargado: 5519108a-263.jpg
# [273/300] ✅ Descargado: a55c6918-265.jpg
# [274/300] ✅ Descargado: f847547e-268.jpg
# [275/300] ✅ Descargado: 45d11ac8-269.jpg
# [276/300] ✅ Descargado: 4f651696-273.jpg
# [277/300] ✅ Descargado: 832bb328-274.jpg
# [278/300] ✅ Descargado: dbc1c0a5-279.jpg
# [279/300] ✅ Descargado: 18a23598-284.jpg
# [280/300] ✅ Descargado: c4f7b573-289.jpg
# [281/300] ✅ Descargado: a5c3e632-391.jpg
# [282/300] ✅ Descargado: a137c758-393.jpg
# [283/300] ✅ Descargado: 20e51c8a-394.jpg
# [284/300] ✅ Descargado: 02a86720-396.jpg
# [285/300] ✅ Descargado: 686f3c5d-303.jpg
# [286/300] ✅ Descargado: dbefc525-312.jpg
# [287/300] ✅ Descargado: 4aadb1b0-316.jpg
# [288/300] ✅ Descargado: f122247e-320.jpg
# [289/300] ✅ Descargado: 4682d90e-333.jpg
# [290/300] ✅ Descargado: c858a05a-334.jpg
# [291/300] ✅ Descargado: 3baa6f03-339.jpg
# [292/300] ✅ Descargado: d91737b9-344.jpg
# [293/300] ✅ Descargado: 15cbe1df-346.jpg
# [294/300] ✅ Descargado: a2d2cd12-354.jpg
# [295/300] ✅ Descargado: aa6717c3-359.jpg
# [296/300] ✅ Descargado: 7f736b52-361.jpg
# [297/300] ✅ Descargado: 729123e7-366.jpg
# [298/300] ✅ Descargado: c1cff536-372.jpg
# [299/300] ✅ Descargado: 2333fa50-383.jpg
# [300/300] ✅ Descargado: a5de7cc6-387.jpg

# %% [markdown]
# # B. Probar máscaras

# %%
import os
import cv2
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def visualizar_yolo_labels(nombre_base: str,
                           images_dir='../../data/dataset_etiquetado_presidente/b_etiquetados/images',
                           labels_dir='../../data/dataset_etiquetado_presidente/b_etiquetados/labels',
                           classes_file='../../data/dataset_etiquetado_presidente/b_etiquetados/classes.txt',
                           ext='.jpg'):
    """
    Visualiza una imagen junto con sus anotaciones YOLO.

    Args:
        nombre_base (str): Nombre del archivo sin extensión (por ejemplo: '0ace00af-172_votacion').
        images_dir (str): Ruta al directorio de imágenes.
        labels_dir (str): Ruta al directorio de etiquetas.
        classes_file (str): Ruta al archivo con nombres de clases.
        ext (str): Extensión de la imagen (por defecto '.jpg').
    """
    # Construir rutas
    image_path = os.path.join(images_dir, nombre_base + ext)
    label_path = os.path.join(labels_dir, nombre_base + '.txt')

    # Leer clases
    with open(classes_file, 'r', encoding='utf-8') as f:
        classes = [line.strip() for line in f.readlines()]

    # Leer imagen
    image = cv2.imread(image_path)
    if image is None:
        raise FileNotFoundError(f"No se pudo cargar la imagen: {image_path}")
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    h, w, _ = image.shape

    # Crear figura
    fig, ax = plt.subplots(1, figsize=(10, 10))
    ax.imshow(image)

    # Leer etiquetas
    if os.path.exists(label_path):
        with open(label_path, 'r') as f:
            for line in f:
                parts = line.strip().split()
                if len(parts) != 5:
                    continue  # línea inválida
                class_id = int(parts[0])
                cx, cy, bw, bh = map(float, parts[1:])

                # Convertir a coordenadas absolutas
                x = (cx - bw / 2) * w
                y = (cy - bh / 2) * h
                bw = bw * w
                bh = bh * h

                # Dibujar rectángulo
                rect = patches.Rectangle((x, y), bw, bh, linewidth=2,
                                         edgecolor='lime', facecolor='none')
                ax.add_patch(rect)

                # Añadir nombre de clase
                label = classes[class_id] if class_id < len(classes) else f"Clase {class_id}"
                ax.text(x, y - 5, label, color='lime', fontsize=12,
                        bbox=dict(facecolor='black', alpha=0.5, edgecolor='none'))
    else:
        print(f"⚠️ No se encontró la etiqueta: {label_path}")

    ax.axis('off')
    ax.set_title(f"Visualización: {nombre_base + ext}")
    plt.show()

# %%
visualizar_yolo_labels('0a445921-202')
